# %% [markdown]
# <a href="https://colab.research.google.com/github/fetrentin7/pythonProject/blob/master/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classe Grafos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class Grafos:
  def __init__(self, direcionado = False, ponderado = False):
    self.ponderado = ponderado
    self.direcionado = direcionado

    self.vertices = 0
    self.arestas = 0

# %% [markdown]
# # GrafoMatriz

# %%
class GrafoMatriz(Grafos):
  def __init__(self, direcionado = False, ponderado = False):
    super().__init__(direcionado, ponderado)
    self.matriz = list()
    self.labels = dict() #Contém os nomes de vértices

  def __str__(self): #imprimeGrafo
    return (str(self.matriz))

  def _balanceamentoVerticeRemover(self, idVertice):
    #Ajusta o comprimento do vértice, após remoções
    matrizTmp = list()
    for verticeAtual in self.matriz:
      verticeTmp = list()
      for idx, aresta in enumerate(verticeAtual):
        if idx == idVertice:
          continue
        verticeTmp.append(aresta)
      matrizTmp.append(verticeTmp)
    self.matriz = matrizTmp

  def _balanceamentoMatriz(self):
    #Ajusta o comprimento da matriz
    arestasDaVerticeAtual = list()
    for vertice in range(self.vertices - 1):
      arestasDaVerticeAtual = self.matriz[vertice]
      arestasDaVerticeAtual.append([0, 0])
      self.matriz[vertice] = arestasDaVerticeAtual

  def inserirVertice(self, label):
    #Adiciona um vértice sem nenhuma aresta associada a ele, pode parecer 
    # igual em ambos os casos, mas não é.
    #Precisamos adicionar esse vértice no vetor de vértices e também alocar
    # seu espaço para as arestas.

    #Define nome da vértice
    self.labels[label] = self.vertices
    self.vertices += 1

    #Cria linha com arestas para a nova vértice
    arestasDaVerticeAtual = list()

    for vertice in range(self.vertices):
      arestasDaVerticeAtual.append([0, 0])

    self.matriz.append(arestasDaVerticeAtual)

    if self.vertices > 1:
      self._balanceamentoMatriz()
  
  def removerVertice(self, label):
    #Remove um vértice do grafo, elimina a linha e coluna dele da matriz e a 
    # referência dele da lista, junto com todas as arestas que chegam e saem 
    # dele.
    #Converte o indice para label
    if isinstance(label, int):
      label = self.labelVertice(label)
    
    #Removendo o label
    idVertice = self.labels.get(label)
    self.labels.pop(label)
    #Balanceando os labels
    labelsTmp = dict()
    count = 0
    for label in self.labels.items():
      labelsTmp[label[0]] = count
      count += 1
    self.labels = labelsTmp
    #Diminuindo o número de vértices
    self.vertices -= 1

    matrizTmp = list()
    for vertice in range(self.vertices + 1):
      if vertice == idVertice:
        continue
      matrizTmp.append(self.matriz[vertice])

    self.matriz = matrizTmp

    #Balanceamento Negativo
    self._balanceamentoVerticeRemover(idVertice)

  def labelVertice(self, indice):
    #Funções básicas para retornar o nome de um vértice.
    # return str(self.labels.get(indice))
    label = [k for k, v in self.labels.items() if v == indice]
    return (label[0])

  def imprimeGrafo(self):
    #Imprimir o grafo no console, tentem deixar próximo da representação 
    # dos slides (não precisa da grade da matriz).
    print('Grafo:')
    print('   ' + str(list(range(len(self.matriz)))))
    for idx, vertice in enumerate(self.matriz):
      print(str(idx) + ': ' + str(vertice))

  def inserirAresta(self, origem, destino, peso = 1): 
    #Essa operação deve ter um cuidado especial,
    # ela deve ser executada levando em conta o tipo do grafo.
    # No caso de um grafo ponderado o peso deve ser aplicado e
    # no caso de um grafo direcionado, uma ligação de volta deve ser adicionada;
    
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)
    #Se não ponderado, o peso é igual a 1
    if not self.ponderado:
      peso = 1

    #Adiciona a ligação
    arestaTmp = list()
    for idx, aresta in enumerate(self.matriz[origem]):
      if idx == destino:
        arestaTmp.append([1, peso])
        continue
      arestaTmp.append(aresta)
    self.matriz[origem] = arestaTmp
    
    #Se direcionado, adiciona a ligação de volta
    if self.direcionado:
      arestaTmp = list()
      for idx, aresta in enumerate(self.matriz[destino]):
        if idx == origem:
          arestaTmp.append([1, peso])
          continue
        arestaTmp.append(aresta)
      self.matriz[destino] = arestaTmp

  def removerAresta(self, origem, destino):
    #Remove uma aresta entre dois vértices no grafo, lembrando 
    # que no grafo não direcionado deve ser removida a aresta de retorno também;
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)

    #Remove a ligação
    arestaTmp = list()
    for idx, aresta in enumerate(self.matriz[origem]):
      if idx == destino:
        arestaTmp.append([0, 0])
        continue
      arestaTmp.append(aresta)
    self.matriz[origem] = arestaTmp
    
    #Se direcionado, remove a ligação de volta
    if self.direcionado:
      arestaTmp = list()
      for idx, aresta in enumerate(self.matriz[destino]):
        if idx == origem:
          arestaTmp.append([0, 0])
          continue
        arestaTmp.append(aresta)
      self.matriz[destino] = arestaTmp

  def existeAresta(self, origem, destino):
    #Verifica a existência de uma aresta, aqui vemos uma diferença 
    # grande entre matriz e lista.
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)

    #for idx, aresta in enumerate(self.matriz[origem]):
    #  if idx == destino and aresta[0] == 1:
    #    return True
    
    if self.matriz[origem][destino][0] == 1:
      return True

    return False

  def pesoAresta(self, origem, destino):
    #Retorne o peso de uma aresta, aqui vemos uma diferença
    # grande entre matriz e lista.
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)
    
    if self.ponderado == False:
      return 0

    for idx, aresta in enumerate(self.matriz[origem]):
      if idx == destino:
        return aresta[1]

    return 0

  def retornarVizinhos(self, vertice):
    #Função para retorno dos vizinhos de um vértice, necessária pois não 
    # teremos acesso a estrutura das arestas para os próximos algoritmos.
    #Converte os labels para indices
    if isinstance(vertice, str):
      vertice = self.labels.get(vertice)

    #Só verifica os vizinhos da vértice, ou seja, não verifica se existem
    # arestas ligadas a vértice atual com origem em outras vértices
    # Dúvida: preciso retornar os antecessores?
    # https://www.inf.ufsc.br/grafos/definicoes/definicao.html#:~:text=ADJAC%C3%8ANCIA,de%20Antonio.
    vizinhosIdx = list()
    for idx, aresta in enumerate(self.matriz[vertice]):
      if aresta[0] == 1:
        tuplaTemp = (self.labelVertice(idx), idx)
        vizinhosIdx.append(tuplaTemp)
    return vizinhosIdx
'''
grafoExemplo = GrafoMatriz(direcionado = False, ponderado = False)
grafoExemplo.inserirVertice('um')
grafoExemplo.inserirVertice('dois')
grafoExemplo.inserirVertice('tres')
# print(grafoExemplo)

# print(grafoExemplo.labelVertice(0))
# print(grafoExemplo.labelVertice(1))

# print(grafoExemplo)

# print(grafoExemplo.labelVertice(0))
# print(grafoExemplo.labelVertice(1))

grafoExemplo.imprimeGrafo()

grafoExemplo.inserirAresta(0, 1)
grafoExemplo.removerVertice('tres')
grafoExemplo.imprimeGrafo()
print(grafoExemplo.existeAresta(0, 1))
print(grafoExemplo.existeAresta(1, 0))
# print(grafoExemplo.pesoAresta(0, 1))
# print(grafoExemplo.pesoAresta(1, 0))
print(grafoExemplo.retornarVizinhos(0))
print(grafoExemplo.retornarVizinhos(1))

grafoExemplo.removerAresta(0, 1)
grafoExemplo.imprimeGrafo()
# print(grafoExemplo.existeAresta(0, 1))
# print(grafoExemplo.existeAresta(1, 0))
# print(grafoExemplo.pesoAresta(0, 1))
# print(grafoExemplo.pesoAresta(1, 0))
print(grafoExemplo.retornarVizinhos(0))
print(grafoExemplo.retornarVizinhos(1))
'''
# Out:
# "\ngrafoExemplo = GrafoMatriz(direcionado = False, ponderado = False)\ngrafoExemplo.inserirVertice('um')\ngrafoExemplo.inserirVertice('dois')\ngrafoExemplo.inserirVertice('tres')\n# print(grafoExemplo)\n\n# print(grafoExemplo.labelVertice(0))\n# print(grafoExemplo.labelVertice(1))\n\n# print(grafoExemplo)\n\n# print(grafoExemplo.labelVertice(0))\n# print(grafoExemplo.labelVertice(1))\n\ngrafoExemplo.imprimeGrafo()\n\ngrafoExemplo.inserirAresta(0, 1)\ngrafoExemplo.removerVertice('tres')\ngrafoExemplo.imprimeGrafo()\nprint(grafoExemplo.existeAresta(0, 1))\nprint(grafoExemplo.existeAresta(1, 0))\n# print(grafoExemplo.pesoAresta(0, 1))\n# print(grafoExemplo.pesoAresta(1, 0))\nprint(grafoExemplo.retornarVizinhos(0))\nprint(grafoExemplo.retornarVizinhos(1))\n\ngrafoExemplo.removerAresta(0, 1)\ngrafoExemplo.imprimeGrafo()\n# print(grafoExemplo.existeAresta(0, 1))\n# print(grafoExemplo.existeAresta(1, 0))\n# print(grafoExemplo.pesoAresta(0, 1))\n# print(grafoExemplo.pesoAresta(1, 0))\nprint(grafoExemplo.retornarVizinhos(0))\nprint(grafoExemplo.retornarVizinhos(1))\n"

# %% [markdown]
# # GrafoLista

# %%
from typing_extensions import Self
from operator import itemgetter
from queue import PriorityQueue
class GrafoLista(Grafos):

  def __init__(self, direcionado = False, ponderado= False):
    super().__init__(direcionado, ponderado)
    self.lista = list()
    self.labels = dict() #Contém os nomes de vértices

    self.vertices = 0
    self.arestas = 0

  def __str__(self):
    return (str(self.lista))

  def openFile(self, filename):
    if self.vertices != 0 or self.arestas != 0:
      raise Exception('A instância do objeto GrafoLista não está vazia.')

    with open(filename, 'r') as arquivo:
      verticesArquivo, arestasArquivo, direcionadoArquivo, ponderadoArquivo = (arquivo.readline()).split()
      #Checa se é direcionado
      if int(direcionadoArquivo) == 1:
        self.direcionado = False
      else:
        self.direcionado = True
      #Checa se é ponderado
      if int(ponderadoArquivo) == 1:
        self.ponderado = True
      else:
        self.ponderado = False

      for vertice in range(int(verticesArquivo)):
        self.inserirVertice(str(vertice))

      if self.ponderado:
        for aresta in range(int(arestasArquivo)):
          origem, destino, peso = (arquivo.readline()).split()
          self.inserirAresta(origem, destino, float(peso))
      else:
          for aresta in range(int(arestasArquivo)):
            origem, destino = (arquivo.readline()).split()
            self.inserirAresta(origem, destino)

  def buscaProfunda(self, origem, destino):
    caminho = []
    visitado = set()
    return self._buscaProfunda(origem, destino, caminho, visitado)

  def _buscaProfunda(self, origem, destino, caminho = [], visitado = set()):
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)
    caminho.append(origem)
    visitado.add(origem)
    
    if origem == destino:
        return caminho
    for (vizinho, peso) in self.lista[origem]:
        if vizinho not in visitado:
            resultado = self._buscaProfunda(vizinho, destino, caminho, visitado)
            if resultado is not None:
                return resultado
    #caminho.pop() #diferença entre o visitado e o caminho, sem o pop, ele é igual a ordem visitada
    return None

  def buscaLargura(self, origem, destino, validaDestinoAntes = True, visitadoDebug = False):
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)

    visitados = [origem]
    fila = [origem]

    while len(fila) > 0:
      # print('Laço de repetição!')
      verticeAtual = fila.pop()

      if verticeAtual == destino:
        # print('verticeAtual == destino' + str(verticeAtual) + str(destino), sep=';')
        if verticeAtual not in visitados:
          visitados.append(verticeAtual)
        return visitados

      visinhos = self.retornarVizinhos(verticeAtual)
      # print('VerticeAtual: ' + str(verticeAtual), end=' ')
      # print('Visinhos: ' + str(visinhos))

      for verticeVisinha in visinhos:
        idxVerticeVisinha = self.labels.get(verticeVisinha[0])
        # print('idxVerticeVisinha: ' + str(idxVerticeVisinha))
        if idxVerticeVisinha not in visitados:
          fila.append(idxVerticeVisinha)
          visitados.append(idxVerticeVisinha)
          if idxVerticeVisinha == destino and validaDestinoAntes:
            return visitados
      
      # print('Fila: ' + str(fila), end=' ')
      # print('Visitados: ' + str(visitados))
      # print('Length Fila: ' + str(len(fila)))
      
    if visitadoDebug:
      return visitados
    return None

  def buscaDijkstra(self, origem, destino):
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)

    caminhosMaisCurtos = self.dijkstra(origem)
    return caminhosMaisCurtos[destino]

  def dijkstra(self, origem):
      #Converte os labels para indices
      if isinstance(origem, str):
        origem = self.labels.get(origem)

      caminhosMaisCurtos = {vertice:float('inf') for vertice in range(self.vertices)}
      caminhosMaisCurtos[origem] = 0
      # print('caminhosMaisCurtos inicial:', caminhosMaisCurtos)

      fila = PriorityQueue()
      fila.put((0, origem))
      # print('Fila inicial:', fila.queue)
      visitado = list()

      while not fila.empty():
          (distanciaAtual, verticeAtual) = fila.get()
          visitado.append(verticeAtual)

          vizinhos = self.retornarVizinhos(verticeAtual)
          # print('Vizinhos:', vizinhos)
          # print('Fila loop:', fila.queue)
          for vizinho in vizinhos:
            # print('verticeAtual:', verticeAtual, end=' ')
            # print('VizinhoAtual:', vizinho, end=' ')
            distanciaVizinho = self.pesoArestaLabel(verticeAtual, vizinho[1])
            # print('distanciaVizinhoAtual:', distanciaVizinho)
            if vizinho not in visitado:
              custoAntigo = caminhosMaisCurtos[self.labels.get(vizinho[0])]
              custoNovo = caminhosMaisCurtos[verticeAtual] + distanciaVizinho
              if custoNovo < custoAntigo:
                fila.put((custoNovo, self.labels.get(vizinho[0])))
                caminhosMaisCurtos[self.labels.get(vizinho[0])] = custoNovo

      return caminhosMaisCurtos

  def _ordernarArestasDoVertice(self):
    for verticeId in range(len(self.lista)):
      self.lista[verticeId].sort(key=itemgetter(0))

  def inserirVertice(self, label):
    #Adiciona um vértice sem nenhuma aresta associada a ele, pode parecer 
    # igual em ambos os casos, mas não é.
    #Precisamos adicionar esse vértice no vetor de vértices e também alocar
    # seu espaço para as arestas.

    #Define nome da vértice
    self.labels[label] = self.vertices
    self.vertices += 1

    self.lista.append(list())
  
  def removerVertice(self, label):
    #Remove um vértice do grafo, elimina a linha e coluna dele da matriz 
    # e a referência dele da lista, junto com todas as arestas que chegam 
    # e saem dele.
    #Converte o indice para label
    if isinstance(label, int):
      label = self.labelVertice(label)

    #Removendo o label
    idVertice = self.labels.get(label)
    self.labels.pop(label)
    #Balanceando os labels
    labelsTmp = dict()
    count = 0
    for label in self.labels.items():
      labelsTmp[label[0]] = count
      count += 1
    self.labels = labelsTmp
    #Diminuindo o número de vértices
    self.vertices -= 1

    listaTmp = list()
    for vertice in range(self.vertices + 1):
      if vertice == idVertice:
        continue
      listaTmp.append(self.lista[vertice])

    self.lista = listaTmp
  
  def labelVertice(self, indice):
    #Funções básicas para retornar o nome de um vértice.
    label = [k for k, v in self.labels.items() if v == indice]
    return (label[0])

  def imprimeGrafo(self):
    #Imprimir o grafo no console, tentem deixar próximo da representação 
    # dos slides (não precisa da grade da matriz).
    for valor in range(self.vertices):
      print(valor, ":", self.lista[valor])

  def inserirAresta(self, origem, destino, peso = 1):
    #Essa operação deve ter um cuidado especial,
    # ela deve ser executada levando em conta o tipo do grafo.
    # No caso de um grafo ponderado o peso deve ser aplicado e
    # no caso de um grafo direcionado, uma ligação de volta deve ser adicionada;
    
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)
    #Se não ponderado, o peso é igual a 1
    if not self.ponderado:
      peso = 1
    
    self.lista[origem].append((destino, peso))

    if self.direcionado and origem != destino:
      self.lista[destino].append((origem, peso))

    self._ordernarArestasDoVertice
    #Nao sei calcular o pessoooooooooooooo

  def removerAresta(self, origem, destino):
    #Remove uma aresta entre dois vértices no grafo, lembrando que no grafo
    # não direcionado deve ser removida a aresta de retorno também;
    # try:
      #Converte os labels para indices
      if isinstance(origem, str):
        origem = self.labels.get(origem)
      if isinstance(destino, str):
        destino = self.labels.get(destino)

      for idx, aresta in enumerate(self.lista[origem]):
        if destino in aresta:
          self.lista[origem].pop(idx)

      # self.lista[origem].remove(self.lista[origem][destino])

      #No direcionado, remove o do destino, a origem
      if self.direcionado:
        for idx, aresta in enumerate(self.lista[destino]):
          if origem in aresta:
            self.lista[destino].pop(idx)
        # self.lista[destino].remove(self.lista[origem][destino])

      self._ordernarArestasDoVertice
    # except:
    #   print('Aresta inválida.')

  def existeAresta(self, origem, destino):
    #Verifica a existência de uma aresta, aqui vemos uma diferença
    # grande entre matriz e lista.
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)

    #Verifica se existe o destino na lista, ignorando o peso
    for aresta in self.lista[origem]:
      if destino in aresta:
        return True
      
    return False

  def pesoAresta(self, origem, destino):
    #Retorne o peso de uma aresta, aqui vemos uma diferença grande
    # entre matriz e lista.
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)
    # print('\nPESOARESTA CHAMADO', end=' ')
    # print('origem:', origem, end=' ')
    # print('destino:', destino)

    # print('self.lista[origem]', self.lista[origem])
    # print('self.lista[origem][destino]', self.lista[origem][destino])
    # print('self.lista[origem][destino][1]', self.lista[origem][destino][1])
    return self.lista[origem][destino][1]

  def pesoArestaLabel(self, origem, destino):
    #Retorne o peso de uma aresta, aqui vemos uma diferença grande
    # entre matriz e lista.
    #Converte os labels para indices
    if isinstance(origem, str):
      origem = self.labels.get(origem)
    if isinstance(destino, str):
      destino = self.labels.get(destino)
    # print('\nPESOARESTA CHAMADO', end=' ')
    # print('origem:', origem, end=' ')
    # print('destino:', destino)

    # print('self.lista[origem]', self.lista[origem])
    # print('self.lista[origem][destino]', self.lista[origem][destino])
    # print('self.lista[origem][destino][1]', self.lista[origem][destino][1])
    #Verifica se existe o destino na lista, ignorando o peso
    for aresta in self.lista[origem]:
      # print('aresta:', aresta)
      # print('aresta:', aresta)
      # print('aresta[0]:', aresta[0])
      # print('destino:', aresta[0])
      if destino == aresta[0]:
        return aresta[1] 
    return None    

  def retornarVizinhos(self, vertice):
    #Função para retorno dos vizinhos de um vértice, necessária pois não
    # teremos acesso a estrutura das arestas para os próximos algoritmos.
    vizinhos = list()
    
    #Retorna cada tupla com os vizinhos
    for aresta in self.lista[vertice]:
      tuplaTemp = (self.labelVertice(aresta[0]), aresta[0])
      vizinhos.append(tuplaTemp)

    return vizinhos

# %%
grafoUm = GrafoLista()
grafoUm.openFile('/content/drive/MyDrive/Colab Arquivos (CSV TXT)/Trabalho M1 - Grafos (Dijkstra)/espacoaereo.txt')
grafoUm.imprimeGrafo()
entrada = 5
dijkstra = grafoUm.dijkstra(entrada)
for vertice in range(len(dijkstra)):
    print("Distância do vertice", str(entrada), "para o vertice", str(vertice), "é", str(dijkstra[vertice]), sep=" ")
# print(grafoUm.buscaDijkstra(0, 2))

grafoDois = GrafoLista()
grafoDois.openFile('/content/drive/MyDrive/Colab Arquivos (CSV TXT)/Trabalho M1 - Grafos (Dijkstra)/buscas.txt')
grafoDois.imprimeGrafo()
print(grafoDois.buscaProfunda(0, 4))
print(grafoDois.buscaLargura(0, 4))
# print(grafoDois.retornarVizinhos(0))
# Out:
# 0 : []
# 1 : [(2, 0.0436), (4, 0.0767), (8, 0.1026)]
# 2 : [(1, 0.0436), (4, 0.0515), (8, 0.0866)]
# 3 : [(5, 0.0269), (8, 0.0843)]
# 4 : [(1, 0.0767), (2, 0.0515), (8, 0.0365), (26, 0.0915), (47, 0.2109)]
# 5 : [(3, 0.0269), (8, 0.0849)]
# 6 : [(7, 0.0197), (8, 0.0683), (13, 0.0143)]
# 7 : [(6, 0.0197), (8, 0.0488), (13, 0.014)]
# 8 : [(1, 0.1026), (2, 0.0866), (3, 0.0843), (4, 0.0365), (5, 0.0849), (6, 0.0683), (7, 0.0488), (13, 0.0604), (16, 0.0239), (23, 0.0478), (24, 0.0414), (26, 0.083), (27, 0.0351), (28, 0.1099), (30, 0.0596), (34, 0.0774), (35, 0.0863), (36, 0.1093), (37, 0.1999), (38, 0.1622), (47, 0.1926), (65, 0.204), (67, 0.3284), (112, 0.3847), (118, 0.3655), (144, 0.2746), (201, 0.2654), (248, 0.3059), (313, 0.3829)]
# 9 : [(10, 0.003), (11, 0.0022), (12, 0.0037), (13, 0.0053)]
# 10 : [(9, 0.003), (11, 0.0011), (12, 0.001), (13, 0.0023)]
# 11 : [(9, 0.0022), (10, 0.0011), (13, 0.0033)]
# 12 : [(9, 0.0037), (10, 0.001), (13, 0.002)]
# 13 : [(6, 0.0143), (7, 0.014), (8, 0.0604), (9, 0.0053), (10, 0.0023), (11, 0.0033), (12, 0.002), (14, 0.0009), (15, 0.0011), (17, 0.006), (18, 0.0055), (19, 0.0095), (20, 0.0112), (21, 0.0098)]
# 14 : [(13, 0.0009)]
# 15 : [(13, 0.0011)]
# 16 : [(8, 0.0239), (22, 0.0311)]
# 17 : [(13, 0.006), (19, 0.0038), (20, 0.0053)]
# 18 : [(13, 0.0055)]
# 19 : [(13, 0.0095), (17, 0.0038), (20, 0.0018)]
# 20 : [(13, 0.0112), (17, 0.0053), (19, 0.0018)]
# 21 : [(13, 0.0098)]
# 22 : [(16, 0.0311), (26, 0.0281)]
# 23 : [(8, 0.0478), (24, 0.01)]
# 24 : [(8, 0.0414), (23, 0.01)]
# 25 : [(26, 0.0057)]
# 26 : [(4, 0.0915), (8, 0.083), (22, 0.0281), (25, 0.0057), (29, 0.0131), (31, 0.017), (33, 0.0322), (47, 0.1216)]
# 27 : [(8, 0.0351)]
# 28 : [(8, 0.1099), (35, 0.0425)]
# 29 : [(26, 0.0131), (31, 0.0125), (33, 0.0247), (47, 0.1134)]
# 30 : [(8, 0.0596), (34, 0.0184)]
# Distância do vertice 5 para o vertice 61 é 0.33209999999999995
# Distância do vertice 5 para o vertice 62 é 0.35079999999999995
# Distância do vertice 5 para o vertice 63 é 0.3388999999999999
# Distância do vertice 5 para o vertice 64 é 0.30289999999999995
# Distância do vertice 5 para o vertice 65 é 0.2889
# Distância do vertice 5 para o vertice 66 é 0.29569999999999996
# Distância do vertice 5 para o vertice 67 é 0.4133
# Distância do vertice 5 para o vertice 68 é 0.5477
# Distância do vertice 5 para o vertice 69 é 0.4479
# Distância do vertice 5 para o vertice 70 é 0.47909999999999997
# Distância do vertice 5 para o vertice 71 é 0.4395
# Distância do vertice 5 para o vertice 72 é 0.5292
# Distância do vertice 5 para o vertice 73 é 0.4425
# Distância do vertice 5 para o vertice 74 é 0.3036
# Distância do vertice 5 para o vertice 75 é 0.30319999999999997
# Distância do vertice 5 para o vertice 76 é 0.4146
# Distância do vertice 5 para o vertice 77 é 0.44480000000000003
# Distância do vertice 5 para o vertice 78 é 0.4233
# Distância do vertice 5 para o vertice 79 é 0.4271
# Distância do vertice 5 para o vertice 80 é 0.5343
# Distância do vertice 5 para o vertice 81 é 0.3538
# Distância do vertice 5 para o vertice 82 é 0.4352
# Distância do vertice 5 para o vertice 83 é 0.3258
# Distância do vertice 5 para o vertice 84 é 0.47490000000000004
# Distância do vertice 5 para o vertice 85 é 0.3469
# Distância do vertice 5 para o vertice 86 é 0.33299999999999996
# Distância do vertice 5 para o vertice 87 é 0.3112
# Distância do vertice 5 para o vertice 88 é 0.4646
# Distância do vertice 5 para o vertice 89 é 0.5522
# Distância do vertice 5 para o vertice 90 é 0.4391
# Distância do vertice 5 para o vertice 91 é 0.495
# Distância do vertice 5 para o vertice 92 é 0.5028
# Distância do vertice 5 para o vertice 93 é 0.47159999999999996
# Distância do vertice 5 para o vertice 94 é 0.446
# Distância do vertice 5 para o vertice 95 é 0.4893
# Distância do vertice 5 para o vertice 96 é 0.5348
# Distância do vertice 5 para o vertice 97 é 0.3453
# Distância do vertice 5 para o vertice 98 é 0.39420000000000005
# Distância do vertice 5 para o vertice 99 é 0.4568
# Distância do vertice 5 para o vertice 100 é 0.4669
# Distância do vertice 5 para o vertice 101 é 0.5145
# Distância do vertice 5 para o vertice 102 é 0.4503
# Distância do vertice 5 para o vertice 103 é 0.5186999999999999
# Distância do vertice 5 para o vertice 104 é 0.3394
# Distância do vertice 5 para o vertice 105 é 0.47869999999999996
# Distância do vertice 5 para o vertice 106 é 0.44249999999999995
# Distância do vertice 5 para o vertice 107 é 0.45899999999999996
# Distância do vertice 5 para o vertice 108 é 0.3196
# Distância do vertice 5 para o vertice 109 é 0.5289
# Distância do vertice 5 para o vertice 110 é 0.5374
# Distância do vertice 5 para o vertice 111 é 0.4598
# Distância do vertice 5 para o vertice 112 é 0.46959999999999996
# Distância do vertice 5 para o vertice 113 é 0.5186999999999999
# Distância do vertice 5 para o vertice 114 é 0.45690000000000003
# Distância do vertice 5 para o vertice 115 é 0.5149
# Distância do vertice 5 para o vertice 116 é 0.322
# Distância do vertice 5 para o vertice 117 é 0.5068
# Distância do vertice 5 para o vertice 118 é 0.4504
# Distância do vertice 5 para o vertice 119 é 0.5215
# Distância do vertice 5 para o vertice 120 é 0.443
# Distância do vertice 5 para o vertice 121 é 0.409
# Distância do vertice 5 para o vertice 122 é 0.4931
# Distância do vertice 5 para o vertice 123 é 0.45389999999999997
# Distância do vertice 5 para o vertice 124 é 0.3878
# Distância do vertice 5 para o vertice 125 é 0.5305
# Distância do vertice 5 para o vertice 126 é 0.45890000000000003
# Distância do vertice 5 para o vertice 127 é 0.4716
# Distância do vertice 5 para o vertice 128 é 0.4454
# Distância do vertice 5 para o vertice 129 é 0.5208
# Distância do vertice 5 para o vertice 130 é 0.4503
# Distância do vertice 5 para o vertice 131 é 0.48
# Distância do vertice 5 para o vertice 132 é 0.5159
# Distância do vertice 5 para o vertice 133 é 0.44059999999999994
# Distância do vertice 5 para o vertice 134 é 0.5237
# Distância do vertice 5 para o vertice 135 é 0.4898
# Distância do vertice 5 para o vertice 136 é 0.5191
# Distância do vertice 5 para o vertice 137 é 0.4672
# Distância do vertice 5 para o vertice 138 é 0.3802
# Distância do vertice 5 para o vertice 139 é 0.4848
# Distância do vertice 5 para o vertice 140 é 0.43509999999999993
# Distância do vertice 5 para o vertice 141 é 0.5166
# Distância do vertice 5 para o vertice 142 é 0.34609999999999996
# Distância do vertice 5 para o vertice 143 é 0.5237999999999999
# Distância do vertice 5 para o vertice 144 é 0.35950000000000004
# Distância do vertice 5 para o vertice 145 é 0.4574
# Distância do vertice 5 para o vertice 146 é 0.5194
# Distância do vertice 5 para o vertice 147 é 0.5183
# Distância do vertice 5 para o vertice 148 é 0.4589
# Distância do vertice 5 para o vertice 149 é 0.5126
# Distância do vertice 5 para o vertice 150 é 0.5202
# Distância do vertice 5 para o vertice 151 é 0.3374
# Distância do vertice 5 para o vertice 152 é 0.4916
# Distância do vertice 5 para o vertice 153 é 0.40619999999999995
# Distância do vertice 5 para o vertice 154 é 0.4656
# Distância do vertice 5 para o vertice 155 é 0.4661
# Distância do vertice 5 para o vertice 156 é 0.5193
# Distância do vertice 5 para o vertice 157 é 0.5083
# Distância do vertice 5 para o vertice 158 é 0.4683
# Distância do vertice 5 para o vertice 159 é 0.48210000000000003
# Distância do vertice 5 para o vertice 160 é 0.46509999999999996
# Distância do vertice 5 para o vertice 161 é 0.4777
# Distância do vertice 5 para o vertice 162 é 0.5166
# Distância do vertice 5 para o vertice 163 é 0.47109999999999996
# Distância do vertice 5 para o vertice 164 é 0.47150000000000003
# Distância do vertice 5 para o vertice 165 é 0.3713000000000001
# Distância do vertice 5 para o vertice 166 é 0.39249999999999996
# Distância do vertice 5 para o vertice 167 é 0.47350000000000003
# Distância do vertice 5 para o vertice 168 é 0.38750000000000007
# Distância do vertice 5 para o vertice 169 é 0.3489
# Distância do vertice 5 para o vertice 170 é 0.5215
# Distância do vertice 5 para o vertice 171 é 0.47550000000000003
# Distância do vertice 5 para o vertice 172 é 0.43809999999999993
# Distância do vertice 5 para o vertice 173 é 0.4039
# Distância do vertice 5 para o vertice 174 é 0.5136000000000001
# Distância do vertice 5 para o vertice 175 é 0.412
# Distância do vertice 5 para o vertice 176 é 0.4829
# Distância do vertice 5 para o vertice 177 é 0.511
# Distância do vertice 5 para o vertice 178 é 0.36740000000000006
# Distância do vertice 5 para o vertice 179 é 0.5132
# Distância do vertice 5 para o vertice 180 é 0.46959999999999996
# Distância do vertice 5 para o vertice 181 é 0.4011
# Distância do vertice 5 para o vertice 182 é 0.46009999999999995
# Distância do vertice 5 para o vertice 183 é 0.3549
# Distância do vertice 5 para o vertice 184 é 0.40829999999999994
# Distância do vertice 5 para o vertice 185 é 0.35910000000000003
# Distância do vertice 5 para o vertice 186 é 0.49750000000000005
# Distância do vertice 5 para o vertice 187 é 0.5151
# Distância do vertice 5 para o vertice 188 é 0.4061
# Distância do vertice 5 para o vertice 189 é 0.48419999999999996
# Distância do vertice 5 para o vertice 190 é 0.5202
# Distância do vertice 5 para o vertice 191 é 0.476
# Distância do vertice 5 para o vertice 192 é 0.4901
# Distância do vertice 5 para o vertice 193 é 0.35660000000000003
# Distância do vertice 5 para o vertice 194 é 0.5456000000000001
# Distância do vertice 5 para o vertice 195 é 0.47189999999999993
# Distância do vertice 5 para o vertice 196 é 0.47339999999999993
# Distância do vertice 5 para o vertice 197 é 0.35140000000000005
# Distância do vertice 5 para o vertice 198 é 0.4356
# Distância do vertice 5 para o vertice 199 é 0.35750000000000004
# Distância do vertice 5 para o vertice 200 é 0.3753
# Distância do vertice 5 para o vertice 201 é 0.35030000000000006
# Distância do vertice 5 para o vertice 202 é 0.5192
# Distância do vertice 5 para o vertice 203 é 0.3536000000000001
# Distância do vertice 5 para o vertice 204 é 0.5104
# Distância do vertice 5 para o vertice 205 é 0.3602000000000001
# Distância do vertice 5 para o vertice 206 é 0.45589999999999997
# Distância do vertice 5 para o vertice 207 é 0.47519999999999996
# Distância do vertice 5 para o vertice 208 é 0.45810000000000006
# Distância do vertice 5 para o vertice 209 é 0.4617
# Distância do vertice 5 para o vertice 210 é 0.5288999999999999
# Distância do vertice 5 para o vertice 211 é 0.47819999999999996
# Distância do vertice 5 para o vertice 212 é 0.5273
# Distância do vertice 5 para o vertice 213 é 0.36600000000000005
# Distância do vertice 5 para o vertice 214 é 0.36060000000000003
# Distância do vertice 5 para o vertice 215 é 0.5316
# Distância do vertice 5 para o vertice 216 é 0.4497
# Distância do vertice 5 para o vertice 217 é 0.48899999999999993
# Distância do vertice 5 para o vertice 218 é 0.5197
# Distância do vertice 5 para o vertice 219 é 0.3873
# Distância do vertice 5 para o vertice 220 é 0.49279999999999996
# Distância do vertice 5 para o vertice 221 é 0.5249
# Distância do vertice 5 para o vertice 222 é 0.5029999999999999
# Distância do vertice 5 para o vertice 223 é 0.5267
# Distância do vertice 5 para o vertice 224 é 0.37710000000000005
# Distância do vertice 5 para o vertice 225 é 0.44849999999999995
# Distância do vertice 5 para o vertice 226 é 0.4937
# Distância do vertice 5 para o vertice 227 é 0.5353
# Distância do vertice 5 para o vertice 228 é 0.37470000000000003
# Distância do vertice 5 para o vertice 229 é 0.4356
# Distância do vertice 5 para o vertice 230 é 0.5183
# Distância do vertice 5 para o vertice 231 é 0.43290000000000006
# Distância do vertice 5 para o vertice 232 é 0.48029999999999995
# Distância do vertice 5 para o vertice 233 é 0.4185
# Distância do vertice 5 para o vertice 234 é 0.525
# Distância do vertice 5 para o vertice 235 é 0.5291
# Distância do vertice 5 para o vertice 236 é 0.37800000000000006
# Distância do vertice 5 para o vertice 237 é 0.5254
# Distância do vertice 5 para o vertice 238 é 0.5357
# Distância do vertice 5 para o vertice 239 é 0.47309999999999997
# Distância do vertice 5 para o vertice 240 é 0.4972
# Distância do vertice 5 para o vertice 241 é 0.48410000000000003
# Distância do vertice 5 para o vertice 242 é 0.3834000000000001
# Distância do vertice 5 para o vertice 243 é 0.5362
# Distância do vertice 5 para o vertice 244 é 0.39560000000000006
# Distância do vertice 5 para o vertice 245 é 0.38880000000000003
# Distância do vertice 5 para o vertice 246 é 0.39220000000000005
# Distância do vertice 5 para o vertice 247 é 0.4794
# Distância do vertice 5 para o vertice 248 é 0.39080000000000004
# Distância do vertice 5 para o vertice 249 é 0.5282
# Distância do vertice 5 para o vertice 250 é 0.3972000000000001
# Distância do vertice 5 para o vertice 251 é 0.39260000000000006
# Distância do vertice 5 para o vertice 252 é 0.5362
# Distância do vertice 5 para o vertice 253 é 0.39440000000000003
# Distância do vertice 5 para o vertice 254 é 0.4462
# Distância do vertice 5 para o vertice 255 é 0.5111
# Distância do vertice 5 para o vertice 256 é 0.5021
# Distância do vertice 5 para o vertice 257 é 0.48300000000000004
# Distância do vertice 5 para o vertice 258 é 0.41650000000000004
# Distância do vertice 5 para o vertice 259 é 0.5239
# Distância do vertice 5 para o vertice 260 é 0.5345
# Distância do vertice 5 para o vertice 261 é 0.4666
# Distância do vertice 5 para o vertice 262 é 0.46909999999999996
# Distância do vertice 5 para o vertice 263 é 0.40390000000000004
# Distância do vertice 5 para o vertice 264 é 0.43160000000000004
# Distância do vertice 5 para o vertice 265 é 0.5222
# Distância do vertice 5 para o vertice 266 é 0.4923
# Distância do vertice 5 para o vertice 267 é 0.48350000000000004
# Distância do vertice 5 para o vertice 268 é 0.4809
# Distância do vertice 5 para o vertice 269 é 0.4793
# Distância do vertice 5 para o vertice 270 é 0.4763
# Distância do vertice 5 para o vertice 271 é 0.5024
# Distância do vertice 5 para o vertice 272 é 0.5143
# Distância do vertice 5 para o vertice 273 é 0.533
# Distância do vertice 5 para o vertice 274 é 0.4299000000000001
# Distância do vertice 5 para o vertice 275 é 0.4557
# Distância do vertice 5 para o vertice 276 é 0.44789999999999996
# Distância do vertice 5 para o vertice 277 é 0.4788
# Distância do vertice 5 para o vertice 278 é 0.49460000000000004
# Distância do vertice 5 para o vertice 279 é 0.4895
# Distância do vertice 5 para o vertice 280 é 0.4842
# Distância do vertice 5 para o vertice 281 é 0.5161
# Distância do vertice 5 para o vertice 282 é 0.4889
# Distância do vertice 5 para o vertice 283 é 0.5041
# Distância do vertice 5 para o vertice 284 é 0.5443
# Distância do vertice 5 para o vertice 285 é 0.5273
# Distância do vertice 5 para o vertice 286 é 0.5219
# Distância do vertice 5 para o vertice 287 é 0.5421
# Distância do vertice 5 para o vertice 288 é 0.4835
# Distância do vertice 5 para o vertice 289 é 0.5445
# Distância do vertice 5 para o vertice 290 é 0.5029
# Distância do vertice 5 para o vertice 291 é 0.4994
# Distância do vertice 5 para o vertice 292 é 0.5107
# Distância do vertice 5 para o vertice 293 é 0.4926
# Distância do vertice 5 para o vertice 294 é 0.49860000000000004
# Distância do vertice 5 para o vertice 295 é 0.5505
# Distância do vertice 5 para o vertice 296 é 0.49579999999999996
# Distância do vertice 5 para o vertice 297 é 0.48710000000000003
# Distância do vertice 5 para o vertice 298 é 0.5571
# Distância do vertice 5 para o vertice 299 é 0.5543
# Distância do vertice 5 para o vertice 300 é 0.5625
# Distância do vertice 5 para o vertice 301 é 0.5528
# Distância do vertice 5 para o vertice 302 é 0.5878
# Distância do vertice 5 para o vertice 303 é 0.5156000000000001
# Distância do vertice 5 para o vertice 304 é 0.5192
# Distância do vertice 5 para o vertice 305 é 0.5571
# Distância do vertice 5 para o vertice 306 é 0.5702999999999999
# Distância do vertice 5 para o vertice 307 é 0.5653
# Distância do vertice 5 para o vertice 308 é 0.519
# Distância do vertice 5 para o vertice 309 é 0.5311
# Distância do vertice 5 para o vertice 310 é 0.5744
# Distância do vertice 5 para o vertice 311 é 0.5751
# Distância do vertice 5 para o vertice 312 é 0.4774
# Distância do vertice 5 para o vertice 313 é 0.4678
# Distância do vertice 5 para o vertice 314 é 0.4723
# Distância do vertice 5 para o vertice 315 é 0.475
# Distância do vertice 5 para o vertice 316 é 0.4763
# Distância do vertice 5 para o vertice 317 é 0.4749
# Distância do vertice 5 para o vertice 318 é 0.4857
# Distância do vertice 5 para o vertice 319 é 0.489
# Distância do vertice 5 para o vertice 320 é 0.6718999999999999
# Distância do vertice 5 para o vertice 321 é 0.6761999999999999
# Distância do vertice 5 para o vertice 322 é 0.6808
# Distância do vertice 5 para o vertice 323 é 0.6822999999999999
# Distância do vertice 5 para o vertice 324 é 0.6771999999999999
# Distância do vertice 5 para o vertice 325 é 0.6855999999999999
# Distância do vertice 5 para o vertice 326 é 0.5414
# Distância do vertice 5 para o vertice 327 é 0.7851999999999999
# Distância do vertice 5 para o vertice 328 é 0.7758999999999999
# Distância do vertice 5 para o vertice 329 é 0.7688999999999999
# Distância do vertice 5 para o vertice 330 é 0.8472999999999999
# Distância do vertice 5 para o vertice 331 é 0.8146
# Distância do vertice 5 para o vertice 332 é 0.7864999999999999
# 0 : [(1, 1), (2, 1), (3, 1)]
# 1 : [(0, 1), (3, 1)]
# 2 : [(0, 1), (4, 1), (5, 1)]
# 3 : [(0, 1), (1, 1)]
# 4 : [(2, 1), (5, 1)]
# 5 : [(2, 1), (4, 1)]
# 6 : []
# [0, 1, 3, 2, 4]
# [0, 1, 2, 3, 4]
